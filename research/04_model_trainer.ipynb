# %%
import os

# %%
# %pwd
# Out:
# 'c:\\DataScience\\Projects\\Next_Word_Predictor\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\DataScience\\Projects\\Next_Word_Predictor'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class ModelTrainerConfig:
    root_dir: Path
    array_path: Path
    model_name: str
    units_lstm: int
    units_dense: int
    activation: str
    input_dim: int
    output_dim: int
    input_length:int
    loss: str
    optimizer: str
    metrics: list
    epoch: int

# %%
from NWPproject.constants import *
from NWPproject.utils.common import read_yaml_file, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH,):

        self.config = read_yaml_file(config_filepath)
        self.params = read_yaml_file(params_filepath)

        create_directories([self.config.artifacts_root])

    def get_model_trainer_config(self) -> ModelTrainerConfig:
        config = self.config.model_trainer
        units_lstm_params = self.params.LSTM
        units_dense_params = self.params.Dense
        activation_params = self.params.Dense
        input_dim_params = self.params.Embedding
        output_dim_params = self.params.Embedding
        input_length_params = self.params.Embedding
        loss_params = self.params.compile
        optimizer_params = self.params.compile
        metrics_params = self.params.compile
        epoch_params = self.params.fit

        create_directories([config.root_dir])

        model_trainer_config = ModelTrainerConfig(
            root_dir=config.root_dir,
            array_path=config.array_path,
            model_name=config.model_name,
            units_lstm= units_lstm_params.units_lstm,
            units_dense = units_dense_params.units_dense,
            activation = activation_params.activation,
            input_dim = input_dim_params.input_dim,
            output_dim = output_dim_params.output_dim,
            input_length = input_length_params.input_length,
            loss = loss_params.loss,
            optimizer = optimizer_params.optimizer,
            metrics = metrics_params.metrics,
            epoch = epoch_params.epoch
        )

        return model_trainer_config

# %%
import os
import numpy as np
from NWPproject.logging import logger
import joblib
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding

# %%
class ModelTrainer:
    def __init__(self, config: ModelTrainerConfig):
        self.config = config

    def train(self):
        loaded_arrays = np.load(self.config.array_path)

        loaded_array1 = loaded_arrays['arr1']
        loaded_array2 = loaded_arrays['arr2']
        # loaded_array2=loaded_array2.flatten()

        print("Loaded array1:", type(loaded_array1))
        print("Loaded array2:", type(loaded_array2))

        print(loaded_array1.shape)
        print(loaded_array2.shape)

        model=Sequential()
        model.add(Embedding(self.config.input_dim,self.config.output_dim,input_length=self.config.input_length))
        model.add(LSTM(self.config.units_lstm))
        model.add(Dense(self.config.units_dense,activation=self.config.activation))

        model.compile(loss=self.config.loss,optimizer=self.config.optimizer,metrics=self.config.metrics)
        print(model.summary())

        model.fit(loaded_array1,loaded_array2,epochs=self.config.epoch)

        joblib.dump(model, os.path.join(self.config.root_dir, self.config.model_name))

# %%
try:
    config = ConfigurationManager()
    data_transformation_config = config.get_model_trainer_config()
    data_transformation = ModelTrainer(config=data_transformation_config)
    data_transformation.train()
except Exception as e:
    raise e
# Out:
# [2024-07-03 21:49:38,281: INFO:common: yaml file: config\config.yaml loaded successfully]
# [2024-07-03 21:49:38,291: INFO:common: yaml file: params.yaml loaded successfully]
# [2024-07-03 21:49:38,291: INFO:common: createD Directory at:artifacts]
# [2024-07-03 21:49:38,299: INFO:common: createD Directory at:artifacts/model_trainer]
# Loaded array1: <class 'numpy.ndarray'>
# Loaded array2: <class 'numpy.ndarray'>
# (672, 24)
# (672, 398)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 24, 100)           39800
#
#  lstm (LSTM)                 (None, 100)               80400
#
#  dense (Dense)               (None, 398)               40198
#
# =================================================================
# Total params: 160398 (626.55 KB)
# Trainable params: 160398 (626.55 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/100
# 21/21 [==============================] - 2s 18ms/step - loss: 5.9580 - accuracy: 0.0908
# Epoch 2/100
# 21/21 [==============================] - 0s 19ms/step - loss: 5.6174 - accuracy: 0.1101
# Epoch 3/100
# 21/21 [==============================] - 0s 16ms/step - loss: 5.4060 - accuracy: 0.1101
# Epoch 4/100
# 21/21 [==============================] - 0s 16ms/step - loss:
100
# 21/21 [==============================] - 0s 16ms/step - loss: 1.9600 - accuracy: 0.7262
# Epoch 45/100
# 21/21 [==============================] - 0s 16ms/step - loss: 1.8829 - accuracy: 0.7589
# Epoch 46/100
# 21/21 [==============================] - 0s 16ms/step - loss: 1.8106 - accuracy: 0.7693
# Epoch 47/100
# 21/21 [==============================] - 0s 15ms/step - loss: 1.7386 - accuracy: 0.7857
# Epoch 48/100
# 21/21 [==============================] - 0s 15ms/step - loss: 1.6762 - accuracy: 0.8095
# Epoch 49/100
# 21/21 [==============================] - 0s 16ms/step - loss: 1.6142 - accuracy: 0.8199
# Epoch 50/100
# 21/21 [==============================] - 0s 18ms/step - loss: 1.5461 - accuracy: 0.8393
# Epoch 51/100
# 21/21 [==============================] - 0s 17ms/step - loss: 1.4837 - accuracy: 0.8542
# Epoch 52/100
# 21/21 [==============================] - 0s 16ms/step - loss: 1.4237 - accuracy: 0.8586
# Epoch 53/100
# 21/21 [==============================] - 0s 15ms/step - loss: 1.3666 - accuracy: 0.8735
# Epoch 54/100
# 21/21 [==============================] - 0s 15ms/step - loss: 1.3135 - accuracy: 0.8765
# Epoch 55/100
# 21/21 [==============================] - 0s 17ms/step - loss: 1.2599 - accuracy: 0.8869
# Epoch 56/100
# 21/21 [==============================] - 0s 16ms/step - loss: 1.2106 - accuracy: 0.8973
# Epoch 57/100
# 21/21 [==============================] - 0s 16ms/step - loss: 1.1645 - accuracy: 0.8988
# Epoch 58/100
# 21/21 [==============================] - 0s 16ms/step - loss: 1.1183 - accuracy: 0.9018
# Epoch 59/100
# 21/21 [==============================] - 0s 15ms/step - loss: 1.0719 - accuracy: 0.9092
# Epoch 60/100
# 21/21 [==============================] - 0s 16ms/step - loss: 1.0270 - accuracy: 0.9196
# Epoch 61/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.9855 - accuracy: 0.9167
# Epoch 62/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.9475 - accuracy: 0.9196
# Epoch 63/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.9104 - accuracy: 0.9286
# Epoch 64/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.8736 - accuracy: 0.9286
# Epoch 65/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.8395 - accuracy: 0.9315
# Epoch 66/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.8065 - accuracy: 0.9390
# Epoch 67/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.7784 - accuracy: 0.9375
# Epoch 68/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.7485 - accuracy: 0.9390
# Epoch 69/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.7225 - accuracy: 0.9345
# Epoch 70/100
# 21/21 [==============================] - 0s 20ms/step - loss: 0.6942 - accuracy: 0.9390
# Epoch 71/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.6690 - accuracy: 0.9405
# Epoch 72/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.6461 - accuracy: 0.9405
# Epoch 73/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.6232 - accuracy: 0.9464
# Epoch 74/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.6028 - accuracy: 0.9464
# Epoch 75/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.5820 - accuracy: 0.9479
# Epoch 76/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.5638 - accuracy: 0.9509
# Epoch 77/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.5448 - accuracy: 0.9479
# Epoch 78/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.5272 - accuracy: 0.9494
# Epoch 79/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.5110 - accuracy: 0.9494
# Epoch 80/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.4936 - accuracy: 0.9524
# Epoch 81/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.4795 - accuracy: 0.9479
# Epoch 82/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.4662 - accuracy: 0.9524
# Epoch 83/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4526 - accuracy: 0.9494
# Epoch 84/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.4391 - accuracy: 0.9554
# Epoch 85/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.4277 - accuracy: 0.9539
# Epoch 86/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.4151 - accuracy: 0.9524
# Epoch 87/100
# 21/21 [==============================] - 0s 21ms/step - loss: 0.4048 - accuracy: 0.9524
# Epoch 88/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.3940 - accuracy: 0.9539
# Epoch 89/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.3835 - accuracy: 0.9494
# Epoch 90/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.3737 - accuracy: 0.9524
# Epoch 91/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.3649 - accuracy: 0.9554
# Epoch 92/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.3553 - accuracy: 0.9554
# Epoch 93/100
# 21/21 [==============================] - 0s 18ms/step - loss: 0.3475 - accuracy: 0.9524
# Epoch 94/100
# 21/21 [==============================] - 0s 17ms/step - loss: 0.3389 - accuracy: 0.9583
# Epoch 95/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.3314 - accuracy: 0.9583
# Epoch 96/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.3239 - accuracy: 0.9568
# Epoch 97/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.3163 - accuracy: 0.9554
# Epoch 98/100
# 21/21 [==============================] - 0s 15ms/step - loss: 0.3091 - accuracy: 0.9598
# Epoch 99/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.3030 - accuracy: 0.9554
# Epoch 100/100
# 21/21 [==============================] - 0s 16ms/step - loss: 0.2962 - accuracy: 0.9598
